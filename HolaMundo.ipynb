# %% [markdown]
# # Primer Programa en Python
#
# ## Hola Mundo desde Python
#
# **Nombre:** Kerly Pilco
#
# **Fecha:** 23/06/2026
#
# **Repositorio:** <a href="https://github.com/kelapilco/machinglerning">Link del repositorio de GitHub</a>

# %% [markdown]
# Esta secciòn es para crear una funciòn lambda donde calculo la raiz de un nùmero

# %%
#Comentario en python saludando desde python
print("Hola mundo desde Python")
# Out:
# Hola mundo desde Python
